# %%
# Run this cell to import pyspark and to define start_spark() and stop_spark()

import findspark

findspark.init()

import getpass
import pandas
import pyspark
import random
import re

from IPython.display import display, HTML
from pyspark import SparkContext
from pyspark.sql import SparkSession


# Constants used to interact with Azure Blob Storage using the hdfs command or Spark

global username

username = re.sub('@.*', '', getpass.getuser())


# Functions used below

def dict_to_html(d):
    """Convert a Python dictionary into a two column table for display.
    """

    html = []

    html.append(f'<table width="100%" style="width:100%; font-family: monospace;">')
    for k, v in d.items():
        html.append(f'<tr><td style="text-align:left;">{k}</td><td>{v}</td></tr>')
    html.append(f'</table>')

    return ''.join(html)


def show_as_html(df, n=20):
    """Leverage existing pandas jupyter integration to show a spark dataframe as html.
    
    Args:
        n (int): number of rows to show (default: 20)
    """

    display(df.limit(n).toPandas())

    
def display_spark():
    """Display the status of the active Spark session if one is currently running.
    """
    
    if 'spark' in globals() and 'sc' in globals():

        name = sc.getConf().get("spark.app.name")

        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:green">active</span></b>, look for <code>{name}</code> under the running applications section in the Spark UI.</p>',
            f'<ul>',
            f'<li><a href="http://localhost:{sc.uiWebUrl.split(":")[-1]}" target="_blank">Spark Application UI</a></li>',
            f'</ul>',
            f'<p><b>Config</b></p>',
            dict_to_html(dict(sc.getConf().getAll())),
            f'<p><b>Notes</b></p>',
            f'<ul>',
            f'<li>The spark session <code>spark</code> and spark context <code>sc</code> global variables have been defined by <code>start_spark()</code>.</li>',
            f'<li>Please run <code>stop_spark()</code> before closing the notebook or restarting the kernel or kill <code>{name}</code> by hand using the link in the Spark UI.</li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))
        
    else:
        
        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:red">stopped</span></b>, confirm that <code>{username} (notebook)</code> is under the completed applications section in the Spark UI.</p>',
            f'<ul>',
            f'<li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))


# Functions to start and stop spark

def start_spark(executor_instances=2, executor_cores=1, worker_memory=1, master_memory=1):
    """Start a new Spark session and define globals for SparkSession (spark) and SparkContext (sc).
    
    Args:
        executor_instances (int): number of executors (default: 2)
        executor_cores (int): number of cores per executor (default: 1)
        worker_memory (float): worker memory (default: 1)
        master_memory (float): master memory (default: 1)
    """

    global spark
    global sc

    cores = executor_instances * executor_cores
    partitions = cores * 4
    port = 4000 + random.randint(1, 999)

    spark = (
        SparkSession.builder
        .config("spark.driver.extraJavaOptions", f"-Dderby.system.home=/tmp/{username}/spark/")
        .config("spark.dynamicAllocation.enabled", "false")
        .config("spark.executor.instances", str(executor_instances))
        .config("spark.executor.cores", str(executor_cores))
        .config("spark.cores.max", str(cores))
        .config("spark.driver.memory", f'{master_memory}g')
        .config("spark.executor.memory", f'{worker_memory}g')
        .config("spark.driver.maxResultSize", "0")
        .config("spark.sql.shuffle.partitions", str(partitions))
        .config("spark.kubernetes.container.image", "madsregistry001.azurecr.io/hadoop-spark:v3.3.5-openjdk-8")
        .config("spark.kubernetes.container.image.pullPolicy", "IfNotPresent")
        .config("spark.kubernetes.memoryOverheadFactor", "0.3")
        .config("spark.memory.fraction", "0.1")
        .config("spark.app.name", f"{username} (notebook)")
        .getOrCreate()
    )
    sc = SparkContext.getOrCreate()
    
    display_spark()

    
def stop_spark():
    """Stop the active Spark session and delete globals for SparkSession (spark) and SparkContext (sc).
    """

    global spark
    global sc

    if 'spark' in globals() and 'sc' in globals():

        spark.stop()

        del spark
        del sc

    display_spark()


# Make css changes to improve spark output readability

html = [
    '<style>',
    'pre { white-space: pre !important; }',
    'table.dataframe td { white-space: nowrap !important; }',
    'table.dataframe thead th:first-child, table.dataframe tbody th { display: none; }',
    '</style>',
]
display(HTML(''.join(html)))
# Out:
# <style>pre { white-space: pre !important; }table.dataframe td { white-space: nowrap !important; }table.dataframe thead th:first-child, table.dataframe tbody th { display: none; }</style>

# %%
# Run this cell to start a spark session in this notebook

start_spark(executor_instances=2, executor_cores=1, worker_memory=4, master_memory=1)
# Out:
# Warning: Ignoring non-Spark config property: SPARK_DRIVER_BIND_ADDRESS
# 25/05/24 16:52:36 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/24 16:52:37 WARN Utils: Service 'sparkDriver' could not bind on port 7077. Attempting port 7078.
# 25/05/24 16:52:37 WARN Utils: Service 'sparkDriver' could not bind on port 7078. Attempting port 7079.
# 25/05/24 16:52:37 WARN Utils: Service 'sparkDriver' could not bind on port 7079. Attempting port 7080.
# 25/05/24 16:52:37 WARN Utils: Service 'sparkDriver' could not bind on port 7080. Attempting port 7081.
# 25/05/24 16:52:37 WARN Utils: Service 'sparkDriver' could not bind on port 7081. Attempting port 7082.
# 25/05/24 16:52:37 WARN Utils: Service 'sparkDriver' could not bind on port 7082. Attempting port 7083.
# 25/05/24 16:52:37 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 25/05/24 16:52:37 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 25/05/24 16:52:37 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 25/05/24 16:52:37 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.
# 25/05/24 16:52:37 WARN Utils: Service 'SparkUI' could not bind on port 4045. Attempting port 4046.
# 25/05/24 16:52:37 WARN Utils: Service 'SparkUI' could not bind on port 4046. Attempting port 4047.
# <p><b>Spark</b></p><p>The spark session is <b><span style="color:green">active</span></b>, look for <code>asa349 (notebook)</code> under the running applications section in the Spark UI.</p><ul><li><a href="http://localhost:4047" target="_blank">Spark Application UI</a></li></ul><p><b>Config</b></p><table width="100%" style="width:100%; font-family: monospace;"><tr><td style="text-align:left;">spark.dynamicAllocation.enabled</td><td>false</td></tr><tr><td style="text-align:left;">spark.fs.azure.sas.uco-user.madsstorage002.blob.core.windows.net</td><td>"sp=racwdl&st=2024-09-19T08:00:18Z&se=2025-09-19T16:00:18Z&spr=https&sv=2022-11-02&sr=c&sig=qtg6fCdoFz6k3EJLw7dA8D3D8wN0neAYw8yG4z4Lw2o%3D"</td></tr><tr><td style="text-align:left;">spark.kubernetes.driver.pod.name</td><td>spark-master-driver</td></tr><tr><td style="text-align:left;">spark.driver.port</td><td>7083</td></tr><tr><td style="text-align:left;">spark.fs.azure.sas.campus-user.madsstorage002.blob.core.windows.net</td><td>"sp=racwdl&st=2024-09-19T08:03:31Z&se=2025-09-19T16:03:31Z&spr=https&sv=2022-11-02&sr=c&sig=kMP%2BsBsRzdVVR8rrg%2BNbDhkRBNs6Q98kYY695XMRFDU%3D"</td></tr><tr><td style="text-align:left;">spark.kubernetes.container.image.pullPolicy</td><td>IfNotPresent</td></tr><tr><td style="text-align:left;">spark.driver.memory</td><td>1g</td></tr><tr><td style="text-align:left;">spark.app.submitTime</td><td>1748062356721</td></tr><tr><td style="text-align:left;">spark.executor.instances</td><td>2</td></tr><tr><td style="text-align:left;">spark.serializer.objectStreamReset</td><td>100</td></tr><tr><td style="text-align:left;">spark.driver.maxResultSize</td><td>0</td></tr><tr><td style="text-align:left;">spark.kubernetes.namespace</td><td>asa349</td></tr><tr><td style="text-align:left;">spark.submit.deployMode</td><td>client</td></tr><tr><td style="text-align:left;">spark.master</td><td>k8s://https://kubernetes.default.svc.cluster.local:443</td></tr><tr><td style="text-align:left;">spark.fs.azure</td><td>org.apache.hadoop.fs.azure.NativeAzureFileSystem</td></tr><tr><td style="text-align:left;">spark.app.id</td><td>spark-97e3dbf810c349648f316d47456782a6</td></tr><tr><td style="text-align:left;">spark.memory.fraction</td><td>0.1</td></tr><tr><td style="text-align:left;">spark.executor.memory</td><td>4g</td></tr><tr><td style="text-align:left;">spark.app.name</td><td>asa349 (notebook)</td></tr><tr><td style="text-align:left;">spark.executor.id</td><td>driver</td></tr><tr><td style="text-align:left;">spark.kubernetes.executor.podNamePrefix</td><td>asa349-notebook-5bcf269700a2c859</td></tr><tr><td style="text-align:left;">spark.kubernetes.memoryOverheadFactor</td><td>0.3</td></tr><tr><td style="text-align:left;">spark.driver.host</td><td>spark-master-svc</td></tr><tr><td style="text-align:left;">spark.app.startTime</td><td>1748062356849</td></tr><tr><td style="text-align:left;">spark.ui.port</td><td>${env:SPARK_UI_PORT}</td></tr><tr><td style="text-align:left;">spark.driver.extraJavaOptions</td><td>-Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false -Dderby.system.home=/tmp/asa349/spark/</td></tr><tr><td style="text-align:left;">spark.kubernetes.container.image</td><td>madsregistry001.azu ...

# %%
import os
os.environ["HADOOP_ROOT_LOGGER"] = "ERROR,console"

# %%
# Define the folder name 
folder_name = "Images"

# Create the folder if it does not exist
os.makedirs(folder_name, exist_ok=True)

print(f"Folder '{folder_name}' is ready.")
# Out:
# Folder 'Images' is ready.

# %%
# Spark imports

from pyspark.sql import Row, DataFrame, Window, functions as F
from pyspark.sql.types import *

from pyspark.ml.classification import LogisticRegression
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml.stat import Correlation
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.sql.functions import col, when, rand
from sklearn.metrics import confusion_matrix
from pyspark.sql.functions import rand, row_number


import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Helper functions

def show_class_balance(data, name="data", labelCol="label", return_df=False):
    """
    Show and optionally return class balance based on a label column.

    Args:
        data (pyspark.sql.DataFrame): DataFrame with label column
        name (str): Name of the dataset (used in print output)
        labelCol (str): Column name of the class label
        return_df (bool): If True, returns a Pandas DataFrame with results

    Returns:
        pd.DataFrame (optional): DataFrame with label, count, ratio, and dataset name
    """
    total = data.count()
    counts = data.groupBy(labelCol).count().toPandas()
    counts["ratio"] = counts["count"] / total
    counts["dataset"] = name

    print(f'Class balance [{name}]')
    print(f'total:   {total}')
    print(f'counts:')
    print(counts[["label", "count", "ratio"]])
    print()

    if return_df:
        return counts

    
def with_custom_prediction(
    pred,
    threshold,
    probabilityCol="probability",
    customPredictionCol="customPrediction",
):
    """Helper function to select a custom prediction column for a custom classification threshold.
    
    Args:
        pred (pyspark.sql.DataFrame): datafame with column for probability 
        threshold (float): classification threshold
        probabilityCol (str): probability column name
        customPredictionCol (str): new custom prediction column name
    
    Returns:
        pred (pyspark.sql.DataFrame): dataframe with new colum for custom prediction
    """

    classification_udf = F.udf(lambda x: int(x[1] > threshold), IntegerType())
    
    return pred.withColumn(customPredictionCol, classification_udf(F.col(probabilityCol)))


def show_metrics(
    pred,
    name="data",
    threshold=0.5,
    labelCol="label",
    predictionCol="prediction",
    rawPredictionCol="rawPrediction",
    probabilityCol="probability",
):
    """Helper function to evaluate and show metrics based on a custom classification threshold.
    
    Note that this function does not return anything.
    
    Args:
        pred (pyspark.sql.DataFrame): datafame with column for probability 
        name (str): name to print above metrics for readability 
        threshold (float): classification threshold (default: 0.5)
        predictionCol (str): prediction column name
        rawPredictionCol (str): raw prediction column name
        probabilityCol (str): probability column name
    """

    if threshold != 0.5:

        predictionCol = "customPrediction"
        pred = with_custom_prediction(pred, threshold, probabilityCol=probabilityCol, customPredictionCol=predictionCol)

    total = pred.count()

    nP_actual = pred.filter((F.col(labelCol) == 1)).count()
    nN_actual = pred.filter((F.col(labelCol) == 0)).count()

    nP = pred.filter((F.col(predictionCol) == 1)).count()
    nN = pred.filter((F.col(predictionCol) == 0)).count()
    TP = pred.filter((F.col(predictionCol) == 1) & (F.col(labelCol) == 1)).count()
    FP = pred.filter((F.col(predictionCol) == 1) & (F.col(labelCol) == 0)).count()
    FN = pred.filter((F.col(predictionCol) == 0) & (F.col(labelCol) == 1)).count()
    TN = pred.filter((F.col(predictionCol) == 0) & (F.col(labelCol) == 0)).count()

    if TP + FP > 0:
        precision = TP / (TP + FP)
    else:
        precision = 0
        
    recall = TP / (TP + FN)
    accuracy = (TP + TN) / total

    binary_evaluator = BinaryClassificationEvaluator(
        rawPredictionCol=rawPredictionCol,
        labelCol=labelCol,
        metricName='areaUnderROC',
    )
    auroc = binary_evaluator.evaluate(pred)

    print(f'Metrics [{name}]')
    print(f'')
    print(f'threshold: {threshold}')
    print(f'')
    print(f'total:     {total}')
    print(f'')
    print(f'nP actual: {nP_actual}')
    print(f'nN actual: {nN_actual}')
    print(f'')
    print(f'nP:        {nP}')
    print(f'nN:        {nN}')
    print(f'')
    print(f'TP         {TP}')
    print(f'FP         {FP}')
    print(f'FN         {FN}')
    print(f'TN         {TN}')
    print(f'')
    print(f'precision: {precision:.8f}')
    print(f'recall:    {recall:.8f}')
    print(f'accuracy:  {accuracy:.8f}')
    print(f'')
    print(f'auroc:     {auroc:.8f}')

 # Return metrics as dictionary for plotting
    return {
        "Model": name,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "AUROC": auroc
    }
  
def expand(x, s=0.05, d=0):
    """Expand a two element array about its center point by a relative scale or a fixed offset.
    Args:
        x (list|np.array): two element array
        s (float): relative scale to expand array based on its width x[1] - x[0]
        d (float): fixed offset to expand array
    Returns:
        x (np.array): expanded two element array
    """
    
    x = np.array(x)
    d = d + s * (x[1] - x[0])
    
    return x + np.array([-d, d])

# %%
# Common Function For Correlation

def compute_correlation_matrix(df, drop_col='track_id'):
    # Drop null rows
    df_clean = df.dropna()

    # Drop ID column and keep numeric columns
    feature_cols = [c for c in df_clean.columns if c != drop_col]

    # Assemble vector column
    assembler = VectorAssembler(inputCols=feature_cols, outputCol="features")
    assembled_data = assembler.transform(df_clean).select("features")

    # Compute correlation matrix
    corr_matrix = Correlation.corr(assembled_data, "features", "pearson").collect()[0][0].toArray()

    # Return as pandas DataFrame
    return pd.DataFrame(corr_matrix, columns=feature_cols, index=feature_cols).round(2)

# %% [markdown]
# ## GBTClassifier: Experiment- 8

# %%
#  Load Dataset

df_audio_labeled = spark.read.parquet("wasbs://campus-user@madsstorage002.blob.core.windows.net/asa349/df_audio_labeled.parquet")

# %%
# Show
show_as_html(df_audio_labeled, 5)
# Out:
# 25/05/24 16:52:47 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
#              track_id  area_std_1  area_avg_1  area_avg_2  area_avg_4  \
# 0  TRAAAAK128F9318786    0.981704    2.021018    8.660254   22.893179
# 1  TRAAAAW128F429D538    0.715887    1.394014    8.658693   22.893189
# 2  TRAAAVO128F93133D4    0.563095    1.515127    9.357121   22.877687
# 3  TRAABJV128F1460C49    0.816691    1.513588    9.357984   22.877664
# 4  TRAABPQ128F428F0B0    1.102604    1.691939    8.760453   22.892046
#
#    area_avg_5  area_avg_6  area_avg_10   lpc_sd1   lpc_sd2  ...  \
# 0   25.219859   28.031419    33.466417  0.054479  0.101202  ...
# 1   25.221459   28.032572    31.830776  0.053380  0.230397  ...
# 2   25.210587   28.028051    35.090936  0.038634  0.142194  ...
# 3   25.207465   28.025331    35.710639  0.036438  0.118672  ...
# 4   25.220069   28.031888    32.986191  0.054166  0.177058  ...
#
#    timbral_mfcc5_stdstd  timbral_mfcc6_stdstd  timbral_mfcc7_stdstd  \
# 0              0.104499              0.109120              0.112128
# 1              0.156616              0.195872              0.166790
# 2              0.119092              0.109050              0.128920
# 3              0.123799              0.106342              0.095030
# 4              0.137376              0.137657              0.137885
#
#    timbral_mfcc8_stdstd  timbral_mfcc9_stdstd  timbral_mfcc10_stdstd  \
# 0              0.071208              0.095418               0.084071
# 1              0.168028              0.171646               0.185477
# 2              0.131128              0.116457               0.152924
# 3              0.109053              0.094232               0.087997
# 4              0.097754              0.130586               0.088515
#
#    timbral_mfcc11_stdstd  timbral_mfcc12_stdstd  timbral_chroma_a_avg_stdstd  \
# 0               0.066957               0.083433                     0.165574
# 1               0.172822               0.155627                     0.186397
# 2               0.126964               0.096321                     0.325649
# 3               0.101809               0.084085                     0.224609
# 4               0.090835               0.115658                     0.121116
#
#       genre
# 0  Pop_Rock
# 1       Rap
# 2  Pop_Rock
# 3       RnB
# 4     Latin
#
# [5 rows x 113 columns]

# %%
#  Create Binary Label

df_bin = df_audio_labeled.withColumn("label", when(col("genre") == "Electronic", 1).otherwise(0))

# %%
# Assemble Features

feature_cols = [col for col in df_bin.columns if col not in ("track_id", "genre", "label")]
assembler = VectorAssembler(inputCols=feature_cols, outputCol="features_vec")
df_vec = assembler.transform(df_bin)

# %%
#  Prepare unscaled feature set for GBT
df_gbt_input = df_vec.select("track_id", "features_vec", "label").withColumnRenamed("features_vec", "features")

# %%
#  Stratified split (80/20)
df_gbt_strat = df_gbt_input.withColumn("random", rand())
gbt_window = Window.partitionBy("label").orderBy("random")
df_gbt_strat = df_gbt_strat.withColumn("row", row_number().over(gbt_window))

# Compute split size
gbt_counts = df_gbt_strat.groupBy("label").count().collect()
gbt_split_counts = {row['label']: int(row['count'] * 0.8) for row in gbt_counts}

# Create training set
gbt_train = df_gbt_strat.filter(
    ((col("label") == 0) & (col("row") <= gbt_split_counts[0])) |
    ((col("label") == 1) & (col("row") <= gbt_split_counts[1]))
)

# Create test set
gbt_test = df_gbt_strat.subtract(gbt_train)

# Drop helper columns
gbt_train = gbt_train.drop("random", "row")
gbt_test = gbt_test.drop("random", "row")

# %%
#  Apply observation weighting
gbt_train_weighted = gbt_train.withColumn(
    "weight", when(col("label") == 0, 0.5).otherwise(4.0)
)

# Show
show_as_html(gbt_train_weighted, 10)
# Out:
#              track_id                                           features  \
# 0  TRAAHYK128F932A08F  [1.0532662065268985, 1.6858432266728713, 8.662...
# 1  TRPPZJZ12903CBFFDE  [0.3925824727455597, 1.1993621653252031, 9.357...
# 2  TRYOPSQ128F92FC22F  [0.971914620467282, 1.9338375623052875, 9.3579...
# 3  TRTRSVI12903CC7FB1  [0.6818334078797126, 1.5247510901506998, 9.358...
# 4  TRXWGAH128F4273A70  [0.7870927842867877, 1.8301786121702754, 9.357...
# 5  TRGDNIT128F424EEE1  [0.6807709013329873, 1.4480947499223025, 8.661...
# 6  TROOZBR128F4244567  [0.6389021728057377, 1.1721724687390995, 8.665...
# 7  TRFLBXX128F424F16A  [0.8582378174049025, 1.5830939284781391, 8.665...
# 8  TRDKRSJ128F429BC13  [0.9427378959447925, 1.1413524788951839, 8.323...
# 9  TRDIPYW128E078E0F9  [1.3410354616990732, 1.7154182517543934, 8.660...
#
#    label  weight
# 0      1     4.0
# 1      1     4.0
# 2      1     4.0
# 3      1     4.0
# 4      1     4.0
# 5      1     4.0
# 6      1     4.0
# 7      1     4.0
# 8      1     4.0
# 9      1     4.0

# %%
from pyspark.ml.classification import GBTClassifier

import time

# Train GBTClassifier with timing
start_time = time.time()

gbt = GBTClassifier(
    featuresCol="features",
    labelCol="label",
    weightCol="weight",
    maxIter=30,
    maxDepth=10,
    stepSize=0.2
)

gbt_model = gbt.fit(gbt_train_weighted)

end_time = time.time()
gbt_training_time = end_time - start_time

print(f"Training time (GBTClassifier): {gbt_training_time:.2f} seconds")
# Out:
# 25/05/24 16:54:03 WARN DAGScheduler: Broadcasting large task binary with size 1010.8 KiB
# 25/05/24 16:54:04 WARN DAGScheduler: Broadcasting large task binary with size 1081.4 KiB
# 25/05/24 16:54:05 WARN DAGScheduler: Broadcasting large task binary with size 1095.5 KiB
# 25/05/24 16:54:05 WARN DAGScheduler: Broadcasting large task binary with size 1096.0 KiB
# 25/05/24 16:54:05 WARN DAGScheduler: Broadcasting large task binary with size 1096.6 KiB
# 25/05/24 16:54:06 WARN DAGScheduler: Broadcasting large task binary with size 1097.7 KiB
# 25/05/24 16:54:06 WARN DAGScheduler: Broadcasting large task binary with size 1100.0 KiB
# 25/05/24 16:54:06 WARN DAGScheduler: Broadcasting large task binary with size 1104.5 KiB
# 25/05/24 16:54:07 WARN DAGScheduler: Broadcasting large task binary with size 1113.6 KiB
# 25/05/24 16:54:07 WARN DAGScheduler: Broadcasting large task binary with size 1132.3 KiB
# 25/05/24 16:54:08 WARN DAGScheduler: Broadcasting large task binary with size 1169.1 KiB
# 25/05/24 16:54:09 WARN DAGScheduler: Broadcasting large task binary with size 1240.9 KiB
# 25/05/24 16:54:10 WARN DAGScheduler: Broadcasting large task binary with size 1255.9 KiB
# 25/05/24 16:54:10 WARN DAGScheduler: Broadcasting large task binary with size 1256.4 KiB
# 25/05/24 16:54:11 WARN DAGScheduler: Broadcasting large task binary with size 1257.0 KiB
# 25/05/24 16:54:11 WARN DAGScheduler: Broadcasting large task binary with size 1258.1 KiB
# 25/05/24 16:54:11 WARN DAGScheduler: Broadcasting large task binary with size 1260.4 KiB
# 25/05/24 16:54:11 WARN DAGScheduler: Broadcasting large task binary with size 1264.9 KiB
# 25/05/24 16:54:12 WARN DAGScheduler: Broadcasting large task binary with size 1274.0 KiB
# 25/05/24 16:54:12 WARN DAGScheduler: Broadcasting large task binary with size 1292.7 KiB
# 25/05/24 16:54:13 WARN DAGScheduler: Broadcasting large task binary with size 1328.8 KiB
# 25/05/24 16:54:14 WARN DAGScheduler: Broadcasting large task binary with size 1397.3 KiB
# 25/05/24 16:54:15 WARN DAGScheduler: Broadcasting large task binary with size 1408.1 KiB
# 25/05/24 16:54:15 WARN DAGScheduler: Broadcasting large task binary with size 1408.6 KiB
# 25/05/24 16:54:16 WARN DAGScheduler: Broadcasting large task binary with size 1409.1 KiB
# 25/05/24 16:54:16 WARN DAGScheduler: Broadcasting large task binary with size 1410.3 KiB
# 25/05/24 16:54:16 WARN DAGScheduler: Broadcasting large task binary with size 1412.6 KiB
# 25/05/24 16:54:17 WARN DAGScheduler: Broadcasting large task binary with size 1417.1 KiB
# 25/05/24 16:54:17 WARN DAGScheduler: Broadcasting large task binary with size 1425.9 KiB
# 25/05/24 16:54:18 WARN DAGScheduler: Broadcasting large task binary with size 1443.4 KiB
# 25/05/24 16:54:18 WARN DAGScheduler: Broadcasting large task binary with size 1477.2 KiB
# 25/05/24 16:54:19 WARN DAGScheduler: Broadcasting large task binary with size 1540.8 KiB
# 25/05/24 16:54:20 WARN DAGScheduler: Broadcasting large task binary with size 1551.1 KiB
# 25/05/24 16:54:21 WARN DAGScheduler: Broadcasting large task binary with size 1551.5 KiB
# 25/05/24 16:54:21 WARN DAGScheduler: Broadcasting large task binary with size 1552.1 KiB
# 25/05/24 16:54:21 WARN DAGScheduler: Broadcasting large task binary with size 1553.2 KiB
# 25/05/24 16:54:22 WARN DAGScheduler: Broadcasting large task binary with size 1555.5 KiB
# 25/05/24 16:54:22 WARN DAGScheduler: Broadcasting large task binary with size 1560.0 KiB
# 25/05/24 16:54:22 WARN DAGScheduler: Broadcasting large task binary with size 1569.1 KiB
# 25/05/24 16:54:23 WARN DAGScheduler: Broadcasting large task binary with size 1587.8 KiB
# 25/05/24 16:54:24 WARN DAGScheduler: Broadcasting large task binary with size 1624.0 KiB
# 25/05/24 16:54:24 WARN DAGScheduler: Broadcasting large task binary with size 1694.4 KiB
# 25/05/24 16:54:26 WARN DAGScheduler: Broadcasting large task binary with size 1707.5 KiB
# 25/05/24 16:54:26 WARN DAGScheduler: Broadcasting large task binary with size 1708.0 KiB
# 25/05/24 16:54:26 WARN DAGScheduler: Broadcasting large task binary with size 1708.6 KiB
# 25/05/24 16:54:27 WARN DAGScheduler: Broadcasting large task binary with size 1709.7 KiB
# 25/05/24 16:54:27 WARN DAGScheduler: Broadcasting large task binary with size 1712.0 KiB
# 25/05/24 16:54:27 WARN DAGScheduler: Broadcasting large task binary with size 1716.5 KiB
# 25/05/24 16:54:28 WARN DAGScheduler: Broadcasting large task binary with size 1725.3 KiB
# 25/05/24 16:54:28 WARN DAGScheduler: Broadcasting large task binary with size 1742.8 KiB
# 25/05/24 16:54:29 WARN DAGScheduler: Broadcasting large task binary with size 1774.2 KiB
# 25/05/24 16:54:30 WARN DAGScheduler: Broadcasting large task binary with size 1829.4 KiB
# 25/05/24 16:54:31 WARN DAGScheduler: Broadcasting large task binary with size 1832.3 KiB
# 25/05/24 16:54:31 WARN DAGScheduler: Broadcasting large task binary with size 1832.7 KiB
# 25/05/24 16:54:31 WARN DAGScheduler: Broadcasting large task binary with size 1833.3 KiB
# 25/05/24 16:54:32 WARN DAGScheduler: Broadcasting large task binary with size 1834.4 KiB
# 25/05/24 16:54:32 WARN DAGScheduler: Broadcasting large task binary with size 1836.7 KiB
# 25/05/24 16:54:32 WARN DAGScheduler: Broadcasting large task binary with size 1841.2 KiB
# 25/05/24 16:54:33 WARN DAGScheduler: Broadcasting large task binary with size 1850.3 KiB
# 25/05/24 16:54:33 WARN DAGScheduler: Broadcasting large task binary with size 1869.0 KiB
# 25/05/24 16:54:34 WARN DAGScheduler: Broadcasting large task binary with size 1904.8 KiB
# 25/05/24 16:54:35 WARN DAGScheduler: Broadcasting large task binary with size 1968.7 KiB
# 25/05/24 16:54:36 WARN DAGScheduler: Broadcasting large task binary with size 1975.6 KiB
# 25/05/24 16:54:36 WARN DAGScheduler: Broadcasting large task binary with size 1976.0 KiB
# 25/05/24 16:54:37 WARN DAGScheduler: Broadcasting large task binary with size 1976.6 KiB
# 25/05/24 16:54:37 WARN DAGScheduler: Broadcasting large task binary with size 1977.8 KiB
# 25/05/24 16:54:37 WARN DAGScheduler: Broadcasting large task binary with size 1980.0 KiB
# 25/05/24 16:54:38 WARN DAGScheduler: Broadcasting large task binary with size 1984.5 KiB
# 25/05/24 16:54:38 WARN DAGScheduler: Broadcasting large task binary with size 1993.0 KiB
# 25/05/24 16:54:39 WARN DAGScheduler: Broadcasting large task binary with size 2009.3 KiB
# 25/05/24 16:54:39 WARN DAGScheduler: Broadcasting large task binary with size 2039.4 KiB
# 25/05/24 16:54:40 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/05/24 16:54:41 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/05/24 16:54:42 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/05/24 16:54:42 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/05/24 16:54:42 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/05/24 16:54:42 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/05/24 16:54:43 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/05/24 16:54:43 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/05/24 16:54:44 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/05/24 16:54:45 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/05/24 16:54:45 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/24 16:54:46 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/24 16:54:47 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/24 16:54:47 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/24 16:54:47 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/24 16:54:48 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/24 16:54:48 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/24 16:54:48 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/24 16:54:49 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/24 16:54:50 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/05/24 16:54:50 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/05/24 16:54:51 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/05/24 16:54:52 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/05/24 16:54:52 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/05/24 16:54:52 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/05/24 16:54:53 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/05/24 16:54:53 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/05/24 16:54:53 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/05/24 16:54:54 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/05/24 16:54:55 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/05/24 16:54:55 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/05/24 16:54:56 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/05/24 16:54:57 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/05/24 16:54:57 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/05/24 16:54:57 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/05/24 16:54:58 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/05/24 16:54:58 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/05/24 16:54:59 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/05/24 16:54:59 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/05/24 16:55:00 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/05/24 16:55:00 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/05/24 16:55:01 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/05/24 16:55:02 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/05/24 16:55:02 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/05/24 16:55:02 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/05/24 16:55:03 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/05/24 16:55:03 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/05/24 16:55:04 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/05/24 16:55:04 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/05/24 16:55:05 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/05/24 16:55:06 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/05/24 16:55:07 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/05/24 16:55:08 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/05/24 16:55:08 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/05/24 16:55:08 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/05/24 16:55:08 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/05/24 16:55:09 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/05/24 16:55:09 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/05/24 16:55:10 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/05/24 16:55:11 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/05/24 16:55:11 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/05/24 16:55:12 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/05/24 16:55:13 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/05/24 16:55:13 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/05/24 16:55:13 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/05/24 16:55:14 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/05/24 16:55:14 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/05/24 16:55:15 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/05/24 16:55:15 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/05/24 16:55:16 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/05/24 16:55:17 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/05/24 16:55:18 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/05/24 16:55:18 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/05/24 16:55:18 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/05/24 16:55:19 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/05/24 16:55:19 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/05/24 16:55:19 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/05/24 16:55:20 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/05/24 16:55:20 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/05/24 16:55:21 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/05/24 16:55:22 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/05/24 16:55:23 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/05/24 16:55:24 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/05/24 16:55:24 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/05/24 16:55:24 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/05/24 16:55:25 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/05/24 16:55:25 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/05/24 16:55:25 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/05/24 16:55:26 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/05/24 16:55:27 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/05/24 16:55:27 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/05/24 16:55:28 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/05/24 16:55:29 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/05/24 16:55:29 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/05/24 16:55:29 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/05/24 16:55:30 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/05/24 16:55:30 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/05/24 16:55:31 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/05/24 16:55:31 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/05/24 16:55:32 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/05/24 16:55:33 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/05/24 16:55:34 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/05/24 16:55:34 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/05/24 16:55:35 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/05/24 16:55:35 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/05/24 16:55:35 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 25/05/24 16:55:36 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 25/05/24 16:55:36 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 25/05/24 16:55:37 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 25/05/24 16:55:37 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 25/05/24 16:55:38 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/05/24 16:55:39 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/05/24 16:55:40 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/05/24 16:55:40 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/05/24 16:55:40 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/05/24 16:55:41 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/05/24 16:55:41 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/05/24 16:55:42 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/05/24 16:55:42 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/05/24 16:55:43 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/05/24 16:55:44 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/05/24 16:55:45 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/05/24 16:55:45 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/05/24 16:55:46 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/05/24 16:55:46 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/05/24 16:55:46 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/05/24 16:55:47 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/05/24 16:55:47 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/05/24 16:55:48 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/05/24 16:55:48 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/05/24 16:55:49 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/05/24 16:55:50 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/05/24 16:55:51 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/05/24 16:55:51 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/05/24 16:55:51 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/05/24 16:55:52 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/05/24 16:55:52 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/05/24 16:55:53 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/05/24 16:55:53 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 25/05/24 16:55:54 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 25/05/24 16:55:55 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 25/05/24 16:55:56 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 25/05/24 16:55:57 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 25/05/24 16:55:57 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 25/05/24 16:55:57 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 25/05/24 16:55:57 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 25/05/24 16:55:58 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 25/05/24 16:55:58 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 25/05/24 16:55:59 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 25/05/24 16:55:59 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 25/05/24 16:56:00 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 25/05/24 16:56:01 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 25/05/24 16:56:01 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 25/05/24 16:56:02 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 25/05/24 16:56:02 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 25/05/24 16:56:02 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 25/05/24 16:56:03 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 25/05/24 16:56:03 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 25/05/24 16:56:04 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 25/05/24 16:56:05 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 25/05/24 16:56:06 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 25/05/24 16:56:07 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 25/05/24 16:56:07 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 25/05/24 16:56:07 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 25/05/24 16:56:08 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 25/05/24 16:56:08 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 25/05/24 16:56:09 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 25/05/24 16:56:09 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 25/05/24 16:56:10 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 25/05/24 16:56:11 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 25/05/24 16:56:11 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# [Stage 915:============================>                            (1 + 1) / 2]
# Training time (GBTClassifier): 188.23 seconds

# %%
gbt_model.featureImportances
gbt_model.trees  # list of individual trees
# Out:
# [DecisionTreeRegressionModel: uid=dtr_ba8f712b18aa, depth=10, numNodes=1665, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_699a3d263248, depth=10, numNodes=1915, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_d1e103d03650, depth=10, numNodes=1993, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_d062c9837073, depth=10, numNodes=1743, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_2ebf5765a598, depth=10, numNodes=1971, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_2df37a7cf0b8, depth=10, numNodes=1929, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_00f1ad1a1e00, depth=10, numNodes=1959, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_86db0c7a0e7a, depth=10, numNodes=1857, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_8372a75e1294, depth=10, numNodes=1743, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_77862097564d, depth=10, numNodes=1911, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_0e394850ad8f, depth=10, numNodes=1517, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_1a857acc9995, depth=10, numNodes=1747, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_b9e64a2e047d, depth=10, numNodes=1605, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_f93c70502329, depth=10, numNodes=1827, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_d84ff541c5e2, depth=10, numNodes=1603, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_9b3d69f18bd6, depth=10, numNodes=1729, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_757aa9a0ba90, depth=10, numNodes=1719, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_e89bbfb3b354, depth=10, numNodes=1891, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_0f742853a2cb, depth=10, numNodes=1755, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_66e4be92ccca, depth=10, numNodes=1619, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_7d856b4d6331, depth=10, numNodes=1777, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_532481dbb817, depth=10, numNodes=1541, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_18fe78d932b7, depth=10, numNodes=1891, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_868f8b3e3a09, depth=10, numNodes=1451, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_e945902e49f0, depth=10, numNodes=1743, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_c53ca17eab4c, depth=10, numNodes=1583, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_029756909db7, depth=10, numNodes=1827, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_c02dbd3f80b0, depth=10, numNodes=1563, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_b548b227d95b, depth=10, numNodes=1705, numFeatures=111,
#  DecisionTreeRegressionModel: uid=dtr_620fcca1753e, depth=10, numNodes=1899, numFeatures=111]

# %%
num_trees = len(gbt_model.trees)
print(f"Number of trees in the ensemble: {num_trees}")
# Out:
# Number of trees in the ensemble: 30

# %%
import numpy as np

used_features = np.count_nonzero(gbt_model.featureImportances.toArray())
print(f"Number of features actually used in the model: {used_features}")
# Out:
# Number of features actually used in the model: 111

# %%
tree_model = gbt_model.trees[0]
print(f"Number of nodes in the first tree: {tree_model.numNodes}")
# Out:
# Number of nodes in the first tree: 1665

# %%
# Print just the first 20 lines of the tree structure
tree_lines = tree_model.toDebugString.split('\n')
for line in tree_lines[:20]:
    print(line)
# Out:
# DecisionTreeRegressionModel: uid=dtr_ba8f712b18aa, depth=10, numNodes=1665, numFeatures=111
#   If (feature 58 <= 0.14904308558920024)
#    If (feature 17 <= 0.6865504729062089)
#     If (feature 104 <= 0.09795032976371834)
#      If (feature 3 <= 22.87782643159817)
#       If (feature 44 <= 2.0974127410474535)
#        If (feature 28 <= 0.09193631023329056)
#         If (feature 84 <= 0.20841359733991816)
#          If (feature 19 <= 0.3525951268812427)
#           If (feature 11 <= 0.14206364186996978)
#            Predict: -1.0
#           Else (feature 11 > 0.14206364186996978)
#            If (feature 0 <= 0.4220271898174939)
#             Predict: -1.0
#            Else (feature 0 > 0.4220271898174939)
#             Predict: 1.0
#          Else (feature 19 > 0.3525951268812427)
#           If (feature 107 <= 0.12234682989231731)
#            If (feature 19 <= 0.531304487000398)
#             Predict: 0.8401792382374906

# %%
import re
from collections import Counter

feature_counts = Counter()

for tree in gbt_model.trees:
    debug_str = tree.toDebugString
    feature_indices = re.findall(r'feature (\d+)', debug_str)
    feature_counts.update(map(int, feature_indices))

sorted_feature_counts = sorted(feature_counts.items(), key=lambda x: -x[1])


assembler_input_cols = assembler.getInputCols()

for i, count in sorted_feature_counts[:5]:
    print(f"{assembler_input_cols[i]} (index {i}) used {count} times")
# Out:
# area_std_1 (index 0) used 3074 times
# area_avg_2 (index 2) used 1086 times
# area_avg_4 (index 3) used 1030 times
# area_avg_1 (index 1) used 906 times
# spec_fractionoflowenergywindows_avg (index 36) used 764 times

# %%
#  Get feature names from assembler
feature_names = assembler.getInputCols()

#  Extract importance scores from the GBT model
gbt_importances = gbt_model.featureImportances.toArray()

# Create DataFrame with feature names and importance values
df_gbt_importance = pd.DataFrame({
    "Feature": feature_names,
    "Importance": gbt_importances
})

# Sort by importance and select top 20
df_gbt_top = df_gbt_importance.sort_values("Importance", ascending=False).head(20)

#  Plot top 20 features
plt.figure(figsize=(12, 6))
plt.barh(df_gbt_top["Feature"], df_gbt_top["Importance"], color='coral')
plt.xlabel("Feature Importance")
plt.title("Top 20 Features - GBTClassifier")
plt.gca().invert_yaxis()  # Most important at top
plt.grid(True)
plt.tight_layout()
plt.savefig("Images/gbt_feature_impt.png")
plt.show()

# %%
df_gbt_top
# Out:
#                                  Feature  Importance
# 58                   timbral_rolloff_std    0.088407
# 44                    timbral_mfcc3_mean    0.022731
# 28                spec_rootmeansquare_sd    0.021838
# 17                              lpc_avg2    0.020611
# 100                 timbral_mfcc3_stdstd    0.019376
# 61                     timbral_mfcc1_std    0.017301
# 34                  spec_compactness_avg    0.017037
# 0                             area_std_1    0.016521
# 59                      timbral_flux_std    0.015748
# 36   spec_fractionoflowenergywindows_avg    0.015302
# 104                 timbral_mfcc7_stdstd    0.014977
# 26                  spec_spectralflux_sd    0.014793
# 80                 timbral_mfcc1_meanstd    0.014763
# 69                     timbral_mfcc9_std    0.014524
# 29    spec_fractionoflowenergywindows_sd    0.012540
# 19                              lpc_avg4    0.012368
# 82                 timbral_mfcc3_meanstd    0.012090
# 51                   timbral_mfcc10_mean    0.011902
# 60                     timbral_mfcc0_std    0.011576
# 101                 timbral_mfcc4_stdstd    0.011392

# %%
#  Make predictions
gbt_pred = gbt_model.transform(gbt_test).cache()

# Show predictions
show_as_html(gbt_pred.select("label", "prediction", "probability"))
# Out:
# 25/05/24 16:56:32 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 25/05/24 16:56:34 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
#     label  prediction                                 probability
# 0       0         0.0   [0.9423347884573238, 0.05766521154267623]
# 1       0         0.0  [0.9583250398567014, 0.041674960143298634]
# 2       0         0.0   [0.9645644324100605, 0.03543556758993949]
# 3       1         1.0  [0.048521181789885064, 0.9514788182101149]
# 4       1         1.0   [0.19323892215306868, 0.8067610778469313]
# 5       0         0.0   [0.9742396880925894, 0.02576031190741057]
# 6       0         0.0    [0.7932834493989146, 0.2067165506010854]
# 7       0         0.0   [0.9696993954277578, 0.03030060457224215]
# 8       1         0.0    [0.6620176849948415, 0.3379823150051585]
# 9       0         0.0  [0.9492236828538039, 0.050776317146196126]
# 10      0         0.0    [0.9621031813128047, 0.0378968186871953]
# 11      0         0.0      [0.738412211542661, 0.261587788457339]
# 12      0         0.0   [0.9553324208242803, 0.04466757917571973]
# 13      0         0.0   [0.7962820284468856, 0.20371797155311444]
# 14      0         0.0   [0.9213278331671421, 0.07867216683285794]
# 15      0         0.0    [0.8096826352660601, 0.1903173647339399]
# 16      0         0.0   [0.978573771866919, 0.021426228133081038]
# 17      0         0.0   [0.7542989278535301, 0.24570107214646986]
# 18      0         0.0   [0.9290155833647811, 0.07098441663521893]
# 19      0         0.0    [0.9558479420254018, 0.0441520579745982]

# %%
#  Confusion Matrix
gbt_cm_df = gbt_pred.select("label", "prediction").toPandas()
cm_gbt = confusion_matrix(gbt_cm_df["label"], gbt_cm_df["prediction"])

plt.figure(figsize=(6, 4))
sns.heatmap(cm_gbt, annot=True, fmt="d", cmap="Oranges",
            xticklabels=["Other", "Electronic"],
            yticklabels=["Other", "Electronic"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - GBTClassifier")
plt.tight_layout()
plt.savefig("Images/gbt_confusion_matrix.png")
plt.show()
# Out:
# 25/05/24 16:56:35 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB

# %%
#  Evaluate using helper function
metrics_gbt = show_metrics(gbt_pred, name="GBTClassifier")

# Convert to DataFrame
df_gbt_metrics = pd.DataFrame([metrics_gbt], index=["GBTClassifier"])
# Out:
# 25/05/24 16:56:36 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 25/05/24 16:56:36 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 25/05/24 16:56:37 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 25/05/24 16:56:37 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 25/05/24 16:56:38 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 25/05/24 16:56:38 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 25/05/24 16:56:39 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 25/05/24 16:56:39 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 25/05/24 16:56:40 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 25/05/24 16:56:40 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# Metrics [GBTClassifier]
#
# threshold: 0.5
#
# total:     84121
#
# nP actual: 8133
# nN actual: 75988
#
# nP:        12494
# nN:        71627
#
# TP         5459
# FP         7035
# FN         2674
# TN         68953
#
# precision: 0.43692973
# recall:    0.67121603
# accuracy:  0.88458292
#
# auroc:     0.88257281

# %%
# Run this cell before closing the notebook or kill your spark application by hand using the link in the Spark UI

stop_spark()
# Out:
# 25/05/13 14:56:00 WARN ExecutorPodsWatchSnapshotSource: Kubernetes client has been closed.
# <p><b>Spark</b></p><p>The spark session is <b><span style="color:red">stopped</span></b>, confirm that <code>asa349 (notebook)</code> is under the completed applications section in the Spark UI.</p><ul><li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li></ul>
